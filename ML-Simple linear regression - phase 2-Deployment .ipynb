# %%
#For Deployment, we are importing the pickle as we saved the model in it.
import pickle

# %%
#simply load the model and check with the other input or user inputs.
loaded_model= pickle.load(open("finalized_model_linear.sav",'rb'))
result=loaded_model.predict([[12]])
# Out:
# C:\Users\Rajeshkumar\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#calling the result, to display the result of the model
result
# Out:
# array([[129740.26548933]])
